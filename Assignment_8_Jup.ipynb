# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\hp\\Documents\\Assignment\\Assignment 8\\data.csv')

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.nunique()
# Out:
# date               70
# price            1741
# bedrooms           10
# bathrooms          26
# sqft_living       566
# sqft_lot         3113
# floors              6
# waterfront          2
# view                5
# condition           5
# sqft_above        511
# sqft_basement     207
# yr_built          115
# yr_renovated       60
# street           4525
# city               44
# statezip           77
# country             1
# dtype: int64

# %%
df['condition'].unique()
# Out:
# array([3, 5, 4, 2, 1], dtype=int64)

# %%
df['country'].nunique()
# Out:
# 1

# %%
## Since the dataset contains info only about the USA.. Hence we can easily remove country, statezip, city and street details

# %%
df['date'].unique()
# Out:
# array(['2014-05-02 00:00:00', '2014-05-03 00:00:00',
#        '2014-05-04 00:00:00', '2014-05-05 00:00:00',
#        '2014-05-06 00:00:00', '2014-05-07 00:00:00',
#        '2014-05-08 00:00:00', '2014-05-09 00:00:00',
#        '2014-05-10 00:00:00', '2014-05-11 00:00:00',
#        '2014-05-12 00:00:00', '2014-05-13 00:00:00',
#        '2014-05-14 00:00:00', '2014-05-15 00:00:00',
#        '2014-05-16 00:00:00', '2014-05-17 00:00:00',
#        '2014-05-18 00:00:00', '2014-05-19 00:00:00',
#        '2014-05-20 00:00:00', '2014-05-21 00:00:00',
#        '2014-05-22 00:00:00', '2014-05-23 00:00:00',
#        '2014-05-24 00:00:00', '2014-05-25 00:00:00',
#        '2014-05-26 00:00:00', '2014-05-27 00:00:00',
#        '2014-05-28 00:00:00', '2014-05-29 00:00:00',
#        '2014-05-30 00:00:00', '2014-05-31 00:00:00',
#        '2014-06-01 00:00:00', '2014-06-02 00:00:00',
#        '2014-06-03 00:00:00', '2014-06-04 00:00:00',
#        '2014-06-05 00:00:00', '2014-06-06 00:00:00',
# ...

# %%
## Since data column also not giving any relevant data, so we can drop them...

# %%
df.drop(columns = ['date','street','city','statezip','country'], inplace = True)

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992

# %%
df.shape
# Out:
# (4600, 13)

# %%
df['yr_renovated'].nunique()
# Out:
# 60

# %%
df['yr_built'].nunique()
# Out:
# 115

# %%
## Looking for outliers in the dataset column wise

# %%
IQR = df['price'].quantile(0.75) - df['price'].quantile(0.25)

# %%
IQR
# Out:
# 332087.5

# %%
sns.boxplot(df['price'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
sns.histplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
##The boxplot showing there are a lot of outliers in the price columns..

# %%
Q1 = df['price'].quantile(0.25)

# %%
Q3 = df['price'].quantile(0.75)

# %%
Q3 + 1.5*(IQR)
# Out:
# 1153093.75

# %%
df[df['price'] > Q3 + 1.5*(IQR)]
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 11    1.400000e+06       4.0       2.50         2920      4000     1.5
# 14    1.200000e+06       5.0       2.75         2910      9480     1.5
# 99    1.395000e+06       5.0       3.50         4010      8510     2.0
# 122   2.280000e+06       7.0       8.00        13540    307752     3.0
# ...            ...       ...        ...          ...       ...     ...
# 4348  2.199900e+06       4.0       1.50         1120      5427     1.0
# 4350  2.659000e+07       3.0       2.00         1180      7793     1.0
# 4465  2.560498e+06       3.0       2.50         1710      1664     2.0
# 4467  1.337044e+06       4.0       3.50         4280      9583     2.0
# 4572  1.288333e+06       6.0       4.50         3830      4800     3.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df[df['price'] < Q1 - 1.5*(IQR)]
# Out:
# Empty DataFrame
# Columns: [price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated]
# Index: []

# %%
## There are 240 rows which are having outliers values..

# %%
df = df[df['price'] < Q3 + 1.5*(IQR)]

# %%
## So we have an updated df where outliers are not there from Price column..

# %%
df.shape
# Out:
# (4360, 13)

# %%
df['bedrooms'].nunique()
# Out:
# 10

# %%
sns.boxplot(df['bedrooms'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms'>

# %%
sns.countplot(df['bedrooms'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
## Here very less number for flats are there where number of bedrooms are more than 6

# %%
df = df[df['bedrooms'] < 7]

# %%
df.shape
# Out:
# (4348, 13)

# %%
sns.distplot(df['bedrooms'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='bedrooms', ylabel='Density'>

# %%
## Only 12 rows got deleted so not a big deal..

# %%
df['bathrooms'].value_counts()
# Out:
# 2.50    1147
# 1.00     742
# 1.75     620
# 2.00     422
# 2.25     403
# 1.50     288
# 2.75     261
# 3.00     147
# 3.50     120
# 3.25     103
# 3.75      28
# 0.75      17
# 4.00      15
# 4.50      12
# 4.25      10
# 5.00       4
# 1.25       3
# 4.75       2
# 5.50       1
# 6.25       1
# 5.25       1
# 0.00       1
# Name: bathrooms, dtype: int64

# %%
sns.boxplot(df['bathrooms'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bathrooms'>

# %%
sns.countplot(df['bathrooms'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bathrooms', ylabel='count'>

# %%
sns.distplot(df['bathrooms'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='bathrooms', ylabel='Density'>

# %%
sns.distplot(df['sqft_living'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sqft_living', ylabel='Density'>

# %%
sns.boxplot(df['sqft_living'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sqft_living'>

# %%
## Since there are upper outliers

# %%
Q3 = df['sqft_living'].quantile(0.75)

# %%
Q1 = df['sqft_living'].quantile(0.25)

# %%
df = df[df['sqft_living'] < Q3 + 1.5*(Q3 - Q1)]

# %%
df.shape
# Out:
# (4266, 13)

# %%
sns.boxplot(df['sqft_lot'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sqft_lot'>

# %%
sns.countplot(df['sqft_lot'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sqft_lot', ylabel='count'>

# %%
sns.distplot(df['sqft_lot'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sqft_lot', ylabel='Density'>

# %%
Q3 = df['sqft_lot'].quantile(0.75)

# %%
Q1 = df['sqft_lot'].quantile(0.25)

# %%
df = df[df['sqft_lot'] < Q3 + 1.5*(Q3 - Q1)]

# %%
df.shape
# Out:
# (3784, 13)

# %%
sns.boxplot(df['floors'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='floors'>

# %%
sns.countplot(df['floors'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='floors', ylabel='count'>

# %%
sns.boxplot(df['waterfront'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='waterfront'>

# %%
sns.countplot(df['waterfront'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='waterfront', ylabel='count'>

# %%
df['waterfront'].value_counts()
# Out:
# 0    3778
# 1       6
# Name: waterfront, dtype: int64

# %%
## We can directly drop this coulmn as it is having very lesser variability...

# %%
df.drop(columns = ['waterfront'], inplace = True)

# %%
sns.boxplot(df['view'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='view'>

# %%
sns.countplot(df['view'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='view', ylabel='count'>

# %%
sns.distplot(df['view'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='view', ylabel='Density'>

# %%
df['view'].value_counts()
# Out:
# 0    3523
# 2     140
# 3      49
# 1      48
# 4      24
# Name: view, dtype: int64

# %%
df['condition'].value_counts()
# Out:
# 3    2380
# 4    1019
# 5     361
# 2      21
# 1       3
# Name: condition, dtype: int64

# %%
sns.distplot(df['condition'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='condition', ylabel='Density'>

# %%
## We should drop rows which are lesser than 3

# %%
df = df[df['condition'] > 2]

# %%
df.shape
# Out:
# (3760, 12)

# %%
sns.distplot(df['sqft_above'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sqft_above', ylabel='Density'>

# %%
sns.boxplot(df['sqft_above'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sqft_above'>

# %%
## Lot of outliers are there..

# %%
Q1 = df['sqft_lot'].quantile(0.25)
Q3 = df['sqft_lot'].quantile(0.75)
df = df[df['sqft_lot'] < Q3 + 1.5*(Q3 - Q1)]

# %%
df.shape
# Out:
# (3691, 12)

# %%
sns.distplot(df['sqft_lot'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sqft_lot', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'view', 'condition', 'sqft_above', 'sqft_basement', 'yr_built',
#        'yr_renovated'],
#       dtype='object')

# %%
sns.boxplot(df['sqft_basement'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sqft_basement'>

# %%
Q1 = df['sqft_basement'].quantile(0.25)
Q3 = df['sqft_basement'].quantile(0.75)
#df = df[df['sqft_basement'] < Q3 + 1.5*(Q3 - Q1)]

# %%
Q3
# Out:
# 550.0

# %%
df[df['sqft_basement'] > Q3+1.5*(Q3-Q1)].shape
# Out:
# (42, 12)

# %%
##Since 42 rows contains ouliers in the column sqft_basement.. So we will drop them...

# %%
df = df[df['sqft_basement'] < (Q3 + 1.5*(Q3 - Q1))]

# %%
df = df[df['sqft_basement'] > (Q1 - 1.5*(Q3 - Q1))]

# %%
sns.distplot(df['yr_built'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='yr_built', ylabel='Density'>

# %%
sns.countplot(df['yr_built'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='yr_built', ylabel='count'>

# %%
df['yr_built'].value_counts()
# Out:
# 2005    93
# 2006    93
# 2007    82
# 2008    77
# 2014    74
#         ..
# 1935     5
# 1913     4
# 1933     3
# 1934     2
# 1936     2
# Name: yr_built, Length: 115, dtype: int64

# %%
sns.distplot(df['yr_renovated'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='yr_renovated', ylabel='Density'>

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       2146
# 2003     122
# 2000     119
# 2001      93
# 2009      85
# 2005      80
# 2006      57
# 2004      57
# 1923      49
# 2014      49
# 1994      48
# 1989      46
# 2013      46
# 2011      44
# 2012      40
# 2008      38
# 1988      38
# 1999      35
# 2002      35
# 1993      34
# 1998      33
# 1912      32
# 1983      29
# 1979      27
# 1985      25
# 2010      25
# 1997      23
# 1996      20
# 1982      20
# 1992      18
# 1972      13
# 1956      12
# 1990      11
# 1963      11
# 1969      10
# 1970       9
# 1984       9
# 1968       8
# 1954       7
# 1934       6
# 1974       6
# 1971       5
# 2007       5
# 1958       5
# 1945       4
# 1986       4
# 1955       2
# 1978       2
# 1980       2
# 1981       1
# 1953       1
# 1966       1
# 1948       1
# 1913       1
# Name: yr_renovated, dtype: int64

# %%
##We can directly drop this column as most of them have no renovations.

# %%
df.drop(columns = ['yr_renovated'], inplace = True)

# %%
df.shape
# Out:
# (3649, 11)

# %%
corr = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='rocket_r', linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(x = df['price'], y= df['sqft_living'], hue = df['bedrooms'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(x = df['price'], y= df['sqft_lot'], hue = df['bedrooms'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_lot'>

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  \
# 0  313000.0       3.0       1.50         1340      7912     1.5     0
# 2  342000.0       3.0       2.00         1930     11947     1.0     0
# 3  420000.0       3.0       2.25         2000      8030     1.0     0
# 4  550000.0       4.0       2.50         1940     10500     1.0     0
# 5  490000.0       2.0       1.00          880      6380     1.0     0
#
#    condition  sqft_above  sqft_basement  yr_built
# 0          3        1340              0      1955
# 2          4        1930              0      1966
# 3          4        1000           1000      1963
# 4          4        1140            800      1976
# 5          3         880              0      1938

# %%
sns.distplot(df['sqft_basement'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sqft_basement', ylabel='Density'>

# %%
df['sqft_basement'].value_counts()
# Out:
# 0      2242
# 500      46
# 600      41
# 800      36
# 700      32
#        ...
# 20        1
# 265       1
# 417       1
# 516       1
# 875       1
# Name: sqft_basement, Length: 145, dtype: int64

# %%
## Considering the column sqft basement and making all the values more than 0 as 1..

# %%
df.loc[df['sqft_basement'] > 0, 'sqft_basement'] = 1

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  \
# 0  313000.0       3.0       1.50         1340      7912     1.5     0
# 2  342000.0       3.0       2.00         1930     11947     1.0     0
# 3  420000.0       3.0       2.25         2000      8030     1.0     0
# 4  550000.0       4.0       2.50         1940     10500     1.0     0
# 5  490000.0       2.0       1.00          880      6380     1.0     0
#
#    condition  sqft_above  sqft_basement  yr_built
# 0          3        1340              0      1955
# 2          4        1930              0      1966
# 3          4        1000              1      1963
# 4          4        1140              1      1976
# 5          3         880              0      1938

# %%
## Our data is ready

# %%
from sklearn.model_selection import train_test_split

# %%
Y = df['price']
X = df.drop(columns = ['price'], inplace = True)

# %%
X = df

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.2, random_state = 42)

# %%
## Feature Scaling the data..

# %%
from sklearn.preprocessing import StandardScaler

# %%
Sc_X = StandardScaler()

# %%
X_train_scaled = Sc_X.fit_transform(X_train)
X_test_sclaed = Sc_X.transform(X_test)

# %%
Sc_Y = StandardScaler()
Y_train_scaled = Sc_Y.fit_transform(Y_train.values.reshape(-1,1)).flatten()
Y_test_scaled = Sc_Y.transform(Y_test.values.reshape(-1,1)).flatten()

# %%
## Since its a regression problem statement we are going to use regression techniques like :- Linear, Ridge, Decision Tree Regressor and at last Random Forest Regressor

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_train_scaled, Y_train_scaled)
# Out:
# LinearRegression()

# %%
Y_pred_scaled = lin_reg.predict(X_test_sclaed)
Y_pred_train_scaled = lin_reg.predict(X_train_scaled)

# %%
Y_pred = Sc_Y.inverse_transform(Y_pred_scaled.reshape(-1,1)).flatten()
Y_pred_train = Sc_Y.inverse_transform(Y_pred_train_scaled.reshape(-1,1)).flatten()

# %%
## Now calculating the r2 score of train and test dataset

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
r2_train = r2_score(Y_train, Y_pred_train)
r2_test = r2_score(Y_test, Y_pred)

print("R2_Score for train data :- ", r2_train)
print("R2_Score for test data :-", r2_test)
# Out:
# R2_Score for train data :-  0.4030816700601959
# R2_Score for test data :- 0.42980134502252265

# %%
from sklearn.ensemble import RandomForestRegressor

# Create a Random Forest Regressor
regressor_rf = RandomForestRegressor(n_estimators=100, random_state=42)
regressor_rf.fit(X_train_scaled, Y_train_scaled)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Making predictions
y_pred_tree_scaled = regressor_rf.predict(X_test_sclaed)
y_train_pred_tree_scaled = regressor_rf.predict(X_train_scaled)

# Inverse transform the predictions to original scale
# Assuming sc_y is your StandardScaler instance for the target variable
y_pred_tree = Sc_Y.inverse_transform(y_pred_tree_scaled.reshape(-1, 1)).flatten()
y_train_pred_tree = Sc_Y.inverse_transform(y_train_pred_tree_scaled.reshape(-1, 1)).flatten()

# Calculate R2 score for Decision Tree
r2_tree_train = r2_score(Y_train, y_train_pred_tree)
r2_tree_test = r2_score(Y_test, y_pred_tree)
print("regressor_rf  R2 Train Score:", r2_tree_train)
print("regressor_rf  R2 Test Score:", r2_tree_test)

# Calculate Mean Squared Error for Decision Tree
mse_tree_train = mean_squared_error(Y_train, y_train_pred_tree)
mse_tree_test = mean_squared_error(Y_test, y_pred_tree)
print("regressor_rf  Mean Squared Error of Train:", mse_tree_train)
print("regressor_rf  Mean Squared Error of Test:", mse_tree_test)
# Out:
# regressor_rf  R2 Train Score: 0.9071717465728949
# regressor_rf  R2 Test Score: 0.3710261287894745
# regressor_rf  Mean Squared Error of Train: 4160729228.7542753
# regressor_rf  Mean Squared Error of Test: 26865200256.354206

# %%
from sklearn.linear_model import Ridge
ridge_model = Ridge(alpha= 0.1)
ridge_model.fit(X_train_scaled, Y_train_scaled)
# Out:
# Ridge(alpha=0.1)

# %%
y_pred_scaled = ridge_model.predict(X_test_sclaed)
y_train_pred_scaled = ridge_model.predict(X_train_scaled)

# Inverse transform the predictions to original scale
y_pred = Sc_Y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()
y_train_pred = Sc_Y.inverse_transform(y_train_pred_scaled.reshape(-1, 1)).flatten()

# Calculate R2 score
r2_ridge_train = r2_score(Y_train, y_train_pred)
r2_ridge_test = r2_score(Y_test, y_pred)
print("Ridge R2 Train Score:", r2_ridge_train)
print("Ridge R2 Test Score:", r2_ridge_test)

# Calculate Mean Squared Error
mse_ridge_train = mean_squared_error(Y_train, y_train_pred)
mse_ridge_test = mean_squared_error(Y_test, y_pred)
print("Ridge Mean Squared Error of Train:", mse_ridge_train)
print("Ridge Mean Squared Error of Test:", mse_ridge_test)
# Out:
# Ridge R2 Train Score: 0.4030816265078211
# Ridge R2 Test Score: 0.4298233608373956
# Ridge Mean Squared Error of Train: 26754954790.996574
# Ridge Mean Squared Error of Test: 24353809106.755856
